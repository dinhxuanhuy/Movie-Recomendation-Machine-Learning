# %%
import pandas as pd
films = pd.read_csv('films_vn.csv')

# %%
films.head(10)
# Out:
#    Thứ Hạng                         Phim  \
# 0         1                       Mưa đỏ
# 1         2                          Mai
# 2         3      Lật mặt 7: Một điều ước
# 3         4                    Nhà bà Nữ
# 4         5                       Bố già
# 5         6                Bộ tứ báo thủ
# 6         7            Avengers: Hồi kết
# 7         8   Avatar: Dòng chảy của nước
# 8         9  Lật mặt 6: Tấm vé định mệnh
# 9        11                 Nhà gia tiên
#
#                                                 Link         Đạo diễn  \
# 0  https://vi.wikipedia.org/wiki/M%C6%B0a_%C4%91%...  Đặng Thái Huyền
# 1           https://vi.wikipedia.org/wiki/Mai_(phim)       Trấn Thành
# 2  https://vi.wikipedia.org/wiki/L%E1%BA%ADt_m%E1...           Lý Hải
# 3  https://vi.wikipedia.org/wiki/Nh%C3%A0_b%C3%A0...       Trấn Thành
# 4  https://vi.wikipedia.org/wiki/B%E1%BB%91_gi%C3...       Trấn Thành
# 5  https://vi.wikipedia.org/wiki/B%E1%BB%99_t%E1%...       Trấn Thành
# 6  https://vi.wikipedia.org/wiki/Avengers:_H%E1%B...    Anthony Russo
# 7  https://vi.wikipedia.org/wiki/Avatar:_D%C3%B2n...    James Cameron
# 8  https://vi.wikipedia.org/wiki/L%E1%BA%ADt_m%E1...           Lý Hải
# 9  https://vi.wikipedia.org/wiki/Nh%C3%A0_gia_ti%...        Huỳnh Lập
#
#    Doanh thu (tỷ VNĐ)                                          Diễn viên   Năm
# 0                 552  Đỗ Nhật Hoàng, Lê Hạ Anh, Steven Nguyễn, Phươn...  2025
# 1                 551                                     Phương Anh Đào  2024
# 2                 483                                         Thanh Hiền  2024
# 3                 475                               Trấn Thành, Khả Như,  2023
# 4                 427  Trấn Thành, NSND Ngọc Giàu, Tuấn Trần, Ngân Ch...  2021
# 5                 332                                            Tiểu Vy  2025
# 6                 280                                  Robert Downey Jr.  2019
# 7                 278                                    Sam Worthington  2022
# 8                 273                                Lý Hải, Quốc Cường,  2023
# 9                 243                                          Huỳnh Lập  2025

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# %%
url = films['Link'][0]
print(url)
response = requests.get(url , headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# https://vi.wikipedia.org/wiki/M%C6%B0a_%C4%91%E1%BB%8F_(phim)

# %%
content = soup.find_all('div', class_='mw-heading mw-heading2')
text = []
for c in content :
    if c.text.startswith('Nội') or c.text.startswith('Plot'):
            for element in c.next_siblings:
                if element.name and element.name.startswith('h') or element.name == 'div':
                    break
                elif element.name == 'p':
                    text.append(element.text)
            break 
text
# Out:
# ['Bộ phim kể về cuộc chiến đấu bảo vệ Thành cổ Quảng Trị của Cường và các thành viên khác của Tiểu đội 1, Tiểu đoàn K3 Tam Sơn của Quân Giải phóng, chống lại sự tấn công của Quân lực Việt Nam Cộng hòa có sự hỗ trợ của cố vấn và quân đội Mỹ. Cường là sinh viên tại Nhạc viện Hà Nội, nhưng đã từ bỏ cơ hội du học tại Học viện âm nhạc Tchaikovsky để nhập ngũ. Sau khi được huấn luyện một số kỹ năng chiến đấu cơ bản, Cường cùng các tân binh khác lên đường ra mặt trận. Sau khi được Hồng, một cô gái lái đò đưa qua sông Thạch Hãn trong đêm dưới làn đạn pháo của quân đội Việt Nam Cộng Hòa, Cường cùng với Sen, Bình, Tú, và Hải được bổ sung vào Tiểu đội 1 đang chiến đấu tại Thành cổ Quảng Trị. Tiểu đội 1 lúc đó chỉ còn một mình Nông Văn Tạ còn sống, anh là người lớn tuổi nhất so với nhóm tân binh được bổ sung, và là người có kinh nghiệm chiến đấu nhiều nhất, nên trở thành Tiểu đội trưởng của Tiểu đội 1. Trong khi chiến đấu, Cường bị thương nặng, và được đưa ra chữa trị tại Trạm quân y dã chiến bên ngoài Thành cổ. Tại đây, Hồng trong vai trò y tá của Trạm quân y đã chăm sóc hàng ngày cho Cường. Hai người nảy sinh tình cảm và hẹn ước cùng nhau về thăm mẹ của Cường khi đất nước hòa bình. Sau khi được chữa trị, Cường tình nguyện trở lại Thành cổ để chiến đấu cùng Tiểu đội 1. Các thành viên của Tiểu đội 1 đều quyết tâm bảo vệ Thành cổ, với khẩu hiệu "K3 Tam Sơn còn, Thành cổ còn", nhưng lần lượt hy sinh, chỉ còn lại Tấn, thành viên nhỏ tuổi nhất và được bổ sung cuối cùng vào Tiểu đội 1.\n']

# %%
for idx,row in films.iterrows():
    url = row['Link']
    response = requests.get(url , headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    content = soup.find_all('div', class_='mw-heading mw-heading2')
    text = []
    for c in content :
        if c.text.startswith('Nội') or c.text.startswith('Plot'):
                for element in c.next_siblings:
                    if element.name and element.name.startswith('h') or element.name == 'div':
                        break
                    elif element.name == 'p':
                        text.append(element.text)
                break 
    films.at[idx, 'Content'] = ' '.join(text)
    print(f'Processed {idx+1}/{len(films)}: {row["Phim"]}')
# Out:
# Processed 1/58: Mưa đỏ
# Processed 2/58: Mai
# Processed 3/58: Lật mặt 7: Một điều ước
# Processed 4/58: Nhà bà Nữ
# Processed 5/58: Bố già
# Processed 6/58: Bộ tứ báo thủ
# Processed 7/58: Avengers: Hồi kết
# Processed 8/58: Avatar: Dòng chảy của nước
# Processed 9/58: Lật mặt 6: Tấm vé định mệnh
# Processed 10/58: Nhà gia tiên
# Processed 11/58: Exhuma: Quật mộ trùng ma
# Processed 12/58: Phù thủy tối thượng trong Đa Vũ trụ hỗn loạn
# Processed 13/58: Minions: Sự trỗi dậy của Gru
# Processed 14/58: Hai Phượng
# Processed 15/58: Cua lại vợ bầu
# Processed 16/58: Avengers: Cuộc chiến vô cực
# Processed 17/58: Bỗng dưng trúng số
# Processed 18/58: Mắt biếc
# Processed 19/58: Thám tử lừng danh Conan: Dư ảnh của độc nhãn
# Processed 20/58: Tiệc trăng máu
# Processed 21/58: Địa đạo: Mặt trời trong bóng tối
# Processed 22/58: Mang mẹ đi bỏ
# Processed 23/58: Em chưa 18
# Processed 24/58: Doraemon: Nobita và cuộc phiêu lưu vào thế giới trong tranh
# Processed 25/58: Kong: Đảo Đầu lâu
# Processed 26/58: Gái già lắm chiêu 3
# Processed 27/58: Fast & Furious 8
# Processed 28/58: Aquaman: Đế vương Atlantis
# Processed 29/58: Fast & Furious: Hobbs & Shaw
# Processed 30/58: Lật mặt: 48h
# Processed 31/58: Doraemon: Nobita và bản giao hưởng Địa Cầu
# Processed 32/58: Fast & Furious 7
# Processed 33/58: Godzilla x Kong: Đế chế mới
# Processed 34/58: Đất rừng phương Nam
# Processed 35/58: Godzilla đại chiến Kong
# Processed 36/58: Kẻ trộm Mặt Trăng 4
# Processed 37/58: Thanh gươm diệt quỷ: Vô hạn thành
# Processed 38/58: Kung Fu Panda 4
# Processed 39/58: Ma da
# Processed 40/58: Người Nhện: Không còn nhà
# Processed 41/58: Avengers: Đế chế Ultron
# Processed 42/58: Siêu lừa gặp siêu lầy
# Processed 43/58: Chị chị em em 2
# Processed 44/58: Thor: Tình yêu và sấm sét
# Processed 45/58: Thám tử lừng danh Conan: Ngôi sao 5 cánh 1 triệu đô
# Processed 46/58: Người Nhện xa nhà
# Processed 47/58: Cám
# Processed 48/58: Đèn âm hồn
# Processed 49/58: Mỹ nhân ngư
# Processed 50/58: Thế Giới Khủng Long
# Processed 51/58: Gặp lại chị bầu
# Processed 52/58: Black Panther: Chiến binh Báo Đen
# Processed 53/58: Em là bà nội của anh
# Processed 54/58: Để Mai tính 2
# Processed 55/58: Em và Trịnh
# Processed 56/58: Fast & Furious X
# Processed 57/58: Tee Yod: Quỷ ăn tạng 2
# Processed 58/58: Minions

# %%
films.head()
# Out:
#    Thứ Hạng                     Phim  \
# 0         1                   Mưa đỏ
# 1         2                      Mai
# 2         3  Lật mặt 7: Một điều ước
# 3         4                Nhà bà Nữ
# 4         5                   Bố già
#
#                                                 Link         Đạo diễn  \
# 0  https://vi.wikipedia.org/wiki/M%C6%B0a_%C4%91%...  Đặng Thái Huyền
# 1           https://vi.wikipedia.org/wiki/Mai_(phim)       Trấn Thành
# 2  https://vi.wikipedia.org/wiki/L%E1%BA%ADt_m%E1...           Lý Hải
# 3  https://vi.wikipedia.org/wiki/Nh%C3%A0_b%C3%A0...       Trấn Thành
# 4  https://vi.wikipedia.org/wiki/B%E1%BB%91_gi%C3...       Trấn Thành
#
#    Doanh thu (tỷ VNĐ)                                          Diễn viên  \
# 0                 552  Đỗ Nhật Hoàng, Lê Hạ Anh, Steven Nguyễn, Phươn...
# 1                 551                                     Phương Anh Đào
# 2                 483                                         Thanh Hiền
# 3                 475                               Trấn Thành, Khả Như,
# 4                 427  Trấn Thành, NSND Ngọc Giàu, Tuấn Trần, Ngân Ch...
#
#     Năm                                            Content
# 0  2025  Bộ phim kể về cuộc chiến đấu bảo vệ Thành cổ Q...
# 1  2024  Mai là một cô gái sinh ra trong một gia đình b...
# 2  2024  Phim kể về cuộc sống của bà Hai, một bà lão 73...
# 3  2023  Bộ phim xoay quanh gia đình ba thế hệ của bà N...
# 4  2021  Tại một xóm lao động nghèo tại Sài Gòn, có bốn...

# %%
import re 
def clean_text(text):
    text = re.sub(r'\[\d+\]', '', text)  # Remove reference numbers like [1], [2], etc.
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = text.strip()  # Remove leading and trailing whitespace
    return text

# %%
films['Content'] = films['Content'].apply(clean_text)

# %%
films['Content'].head()
# Out:
# 0    Bộ phim kể về cuộc chiến đấu bảo vệ Thành cổ Q...
# 1    Mai là một cô gái sinh ra trong một gia đình b...
# 2    Phim kể về cuộc sống của bà Hai, một bà lão 73...
# 3    Bộ phim xoay quanh gia đình ba thế hệ của bà N...
# 4    Tại một xóm lao động nghèo tại Sài Gòn, có bốn...
# Name: Content, dtype: object

# %%
films.to_csv('films_vn_with_content.csv', index='Thứ Hạng')

# %%
import pandas as pd
films = pd.read_csv('films_vn_with_content.csv')

# %%
films.head(20)
# Out:
#     Unnamed: 0  Thứ Hạng                                          Phim  \
# 0            0         1                                        Mưa đỏ
# 1            1         2                                           Mai
# 2            2         3                       Lật mặt 7: Một điều ước
# 3            3         4                                     Nhà bà Nữ
# 4            4         5                                        Bố già
# 5            5         6                                 Bộ tứ báo thủ
# 6            6         7                             Avengers: Hồi kết
# 7            7         8                    Avatar: Dòng chảy của nước
# 8            8         9                   Lật mặt 6: Tấm vé định mệnh
# 9            9        11                                  Nhà gia tiên
# 10          10        13                      Exhuma: Quật mộ trùng ma
# 11          11        15  Phù thủy tối thượng trong Đa Vũ trụ hỗn loạn
# 12          12        16                  Minions: Sự trỗi dậy của Gru
# 13          13        17                                    Hai Phượng
# 14          14        18                                Cua lại vợ bầu
# 15          15        19                   Avengers: Cuộc chiến vô cực
# 16          16        20                            Bỗng dưng trúng số
# 17          17        21                                      Mắt biếc
# 18          18        22  Thám tử lừng danh Conan: Dư ảnh của độc nhãn
# 19          19        23                                Tiệc trăng máu
#
#                                                  Link           Đạo diễn  \
# 0   https://vi.wikipedia.org/wiki/M%C6%B0a_%C4%91%...    Đặng Thái Huyền
# 1            https://vi.wikipedia.org/wiki/Mai_(phim)         Trấn Thành
# 2   https://vi.wikipedia.org/wiki/L%E1%BA%ADt_m%E1...             Lý Hải
# 3   https://vi.wikipedia.org/wiki/Nh%C3%A0_b%C3%A0...         Trấn Thành
# 4   https://vi.wikipedia.org/wiki/B%E1%BB%91_gi%C3...         Trấn Thành
# 5   https://vi.wikipedia.org/wiki/B%E1%BB%99_t%E1%...         Trấn Thành
# 6   https://vi.wikipedia.org/wiki/Avengers:_H%E1%B...      Anthony Russo
# 7   https://vi.wikipedia.org/wiki/Avatar:_D%C3%B2n...      James Cameron
# 8   https://vi.wikipedia.org/wiki/L%E1%BA%ADt_m%E1...             Lý Hải
# 9   https://vi.wikipedia.org/wiki/Nh%C3%A0_gia_ti%...          Huỳnh Lập
# 10  https://vi.wikipedia.org/wiki/Exhuma:_Qu%E1%BA...      Jang Jae-hyun
# 11  https://vi.wikipedia.org/wiki/Ph%C3%B9_th%E1%B...          Sam Raimi
# 12  https://vi.wikipedia.org/wiki/Minions:_S%E1%BB...         Kyle Balda
# 13  https://vi.wikipedia.org/wiki/Hai_Ph%C6%B0%E1%...        Lê Văn Kiệt
# 14  https://vi.wikipedia.org/wiki/Cua_l%E1%BA%A1i_...         Nhất Trung
# 15  https://vi.wikipedia.org/wiki/Avengers:_Cu%E1%...      Anthony Russo
# 16  https://vi.wikipedia.org/wiki/B%E1%BB%97ng_d%C...       Park Gyu-Tae
# 17  https://vi.wikipedia.org/wiki/M%E1%BA%AFt_bi%E...          Victor Vũ
# 18  https://vi.wikipedia.org/wiki/Th%C3%A1m_t%E1%B...  Katsuya Shigehara
# 19  https://vi.wikipedia.org/wiki/Ti%E1%BB%87c_tr%...  Nguyễn Quang Dũng
#
#     Doanh thu (tỷ VNĐ)                                          Diễn viên  \
# 0                  552  Đỗ Nhật Hoàng, Lê Hạ Anh, Steven Nguyễn, Phươn...
# 1                  551                                     Phương Anh Đào
# 2                  483                                         Thanh Hiền
# 3                  475                               Trấn Thành, Khả Như,
# 4                  427  Trấn Thành, NSND Ngọc Giàu, Tuấn Trần, Ngân Ch...
# 5                  332                                            Tiểu Vy
# 6                  280                                  Robert Downey Jr.
# 7                  278                                    Sam Worthington
# 8                  273                                Lý Hải, Quốc Cường,
# 9                  243                                          Huỳnh Lập
# 10                 213             Choi Min-sik, Yoo Hai-jin, Kim Go-eun,
# 11                 201                               Benedict Cumberbatch
# 12                 200                                      Pierre Coffin
# 13                 200                                      Ngô Thanh Vân
# 14                 192                                        Trấn Thành,
# 15                 189  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 16                 182                                       Go Kyung-pyo
# 17                 180                                         Trần Nghĩa
# 18                 175                                   Takayama Minami,
# 19                 175                                           Hồng Ánh
#
#      Năm                                            Content
# 0   2025  Bộ phim kể về cuộc chiến đấu bảo vệ Thành cổ Q...
# 1   2024  Mai là một cô gái sinh ra trong một gia đình b...
# 2   2024  Phim kể về cuộc sống của bà Hai, một bà lão 73...
# 3   2023  Bộ phim xoay quanh gia đình ba thế hệ của bà N...
# 4   2021  Tại một xóm lao động nghèo tại Sài Gòn, có bốn...
# 5   2025                                                NaN
# 6   2019  Phim khởi đầu sau sự kiện Infinity War năm 201...
# 7   2022  Hơn một thập kỷ sau khi người Na'vi đẩy lùi cu...
# 8   2023  Phim kể về tấm vé số có mệnh giá 10 ngàn đồng ...
# 9   2025  Phim xoay quanh gia đình họ Huỳnh với nghề bán...
# 10  2024  Pháp sư Hàn Quốc nổi tiếng Lee Hwa-rim và ngườ...
# 11  2022  America Chavez và một phiên bản của Bác sĩ Ste...
# 12  2022  Năm 1976, tám năm sau các sự kiện của phần phi...
# 13  2019  Hai Phượng sinh ra trong gia đình nhà võ, được...
# 14  2019  Phim mở đầu bằng mối tình kéo dài 7 năm giữa a...
# 15  2018  Sau khi lấy được Viên đá Sức mạnh, một trong s...
# 16  2022  Tác phẩm lấy bối cảnh là khu biên giới quân sự...
# 17  2019  Mắt biếc xoay quanh mối tình đơn phương của Ng...
# 18  2025                                                NaN
# 19  2020  Phim xoay quanh một nhóm bạn thân thiết ở độ t...
